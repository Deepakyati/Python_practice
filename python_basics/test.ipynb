# %% [markdown]
# python basics

# %%
1+1
# Out:
# 2

# %%
print("hi Deepak, you are the best and you are going to rock in 2026, it will be your year. Hurraaa!!!")
# Out:
# hi Deepak, you are the best and you are going to rock in 2026, it will be your year. Hurraaa!!!
